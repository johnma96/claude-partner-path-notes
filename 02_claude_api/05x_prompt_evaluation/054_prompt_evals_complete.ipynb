# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.handler\",\n  \"MemorySize\": 512,\n  \"Timeout\": 60,\n  \"Environment\": {\n    \"Variables\": {\n      \"DATABASE_CONNECTION_STRING\": \"postgresql://user:password@hostname:5432/database\",\n      \"API_KEY\": \"your-api-key-here\"\n    }\n  },\n  \"Events\": {\n    \"S3Event\": {\n      \"Type\": \"S3\",\n      \"Properties\": {\n        \"Bucket\": \"my-bucket\",\n        \"Events\": [\"s3:ObjectCreated:*\", \"s3:ObjectRemoved:*\"]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events, with memory set to 512MB, timeout to 60 seconds, and environment variables for a database connection string and API key",
#       "format": "json",
#       "solution_criteria": "Valid JSON structure containing Lambda configuration with correct memory, timeout, and environment variables nested properly"
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates correct understanding of Lambda JSON configuration structure with properly nested memory, timeout, and environment variables. However, it has two significant issues: (1) critical security flaw with hardcoded credentials that should be externalized, and (2) invalid 'Events' section that doesn't reflect how S3 event sources are actually configured for Lambda. The core requirements are met structurally, but the implementation contains security risks and incorrect event binding approach."
#   },
#   {
#     "output": "\nimport boto3\nfrom datetime import datetime\n\ndef get_s3_file_last_modified(bucket_name: str, file_key: str) -> str:\n    \"\"\"\n    Get the last modified timestamp of an S3 file in ISO 8601 format.\n    \n    Args:\n        bucket_name: Name of the S3 bucket\n        file_key: Key (path) of the file in the bucket\n    \n    Returns:\n        Last modified timestamp in ISO 8601 format\n    \"\"\"\n    s3_client = boto3.client('s3')\n    \n    response = s3_client.head_object(Bucket=bucket_name, Key=file_key)\n    \n    last_modified = response['LastModified']\n    \n    iso_timestamp = last_modified.isoformat()\n    \n    return iso_timestamp\n\n\nif __name__ == \"__main__\":\n    # Example usage\n    bucket = \"my-bucket\"\n    key = \"path/to/file.txt\"\n    timestamp = get_s3_file_last_modified(bucket, key)\n    print(timestamp)\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and file key as parameters and returns the file's last modified timestamp in ISO 8601 format using boto3",
#       "format": "python",
#       "solution_criteria": "Function uses boto3 S3 client, handles the get_object response, extracts LastModified metadata, and returns it in ISO 8601 format"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements the core requirement using boto3's head_object() method and properly formats the timestamp to ISO 8601. However, it lacks production-ready error handling and input validation. The function would fail ungracefully if the bucket doesn't exist, the file key is invalid, or permissions are insufficient. These are critical omissions for AWS code that interacts with external resources."
#   },
#   {
#     "output": "\narn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@_\\-/]+\n",
#     "test_case": {
#       "task": "Create a regex pattern that matches valid AWS IAM role ARNs (format: arn:aws:iam::123456789012:role/RoleName)",
#       "format": "regex",
#       "solution_criteria": "Pattern correctly validates the ARN structure including account ID (12 digits), 'role/' prefix, and alphanumeric role name with hyphens and slashes allowed"
#     },
#     "score": 8.0,
#     "reasoning": "The solution captures the core ARN structure correctly but has critical flaws in boundary matching and character validation. The missing anchors and overly permissive character class significantly reduce pattern reliability. For production use, the pattern should be: ^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9._/-]+$ or similar, with refined character validation."
#   }
# ]
