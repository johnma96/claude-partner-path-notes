# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema  = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"] # Usar cuando se quiere una búsqueda cerrada en un ambiente de confianza, en este caso, esta web tiene solamente artítucos académicos por lo que la búsqueda estará respaldada únicamente en evidencia científica y no en contenido como blogs sin soporte científico
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages)
response
# Out:
# Message(id='msg_01ASYKu6xkUBDMRXGzZeP4ih', container=None, content=[TextBlock(citations=None, text="# Best Exercises for Leg Muscle Growth\n\nThe most effective compound exercises are:\n\n## **Squats** (Top Choice)\n- Targets quads, glutes, hamstrings, and core\n- Barbell back squats are the gold standard\n- Front squats emphasize quads more\n\n## **Romanian Deadlifts**\n- Exceptional for hamstrings and glutes\n- Also builds lower back strength\n\n## **Bulgarian Split Squats**\n- Unilateral movement for balanced development\n- Great for quads and glutes\n\n## **Leg Press**\n- Allows heavy loading with less fatigue\n- Good alternative if squats are problematic\n\n## Quick Tips\n- **Progressive overload** is key—gradually increase weight\n- Aim for 6-12 reps for hypertrophy\n- Train legs 2x per week\n- Don't neglect calves (calf raises)\n\n**The verdict:** If you can only pick one, **barbell squats** give you the most complete leg development. Combine with Romanian deadlifts for a comp
# ...
